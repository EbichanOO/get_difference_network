# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
data = np.deg2rad(np.arange(360))
sin_data = np.sin(data)
plt.plot(data, sin_data)
plt.title("sin")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()

# %%
import chainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-9758b185b742> in <module>()
# ----> 1 import chainer
#
# C:\Program Files\Anaconda3\lib\site-packages\chainer\__init__.py in <module>()
#       7 from chainer import backends  # NOQA
#       8 from chainer import configuration  # NOQA
# ----> 9 from chainer import dataset  # NOQA
#      10 from chainer import datasets  # NOQA
#      11 from chainer import function  # NOQA
#
# C:\Program Files\Anaconda3\lib\site-packages\chainer\dataset\__init__.py in <module>()
#       1 from chainer.dataset import convert  # NOQA
#       2 from chainer.dataset import dataset_mixin  # NOQA
# ----> 3 from chainer.dataset import download  # NOQA
#       4 from chainer.dataset import iterator  # NOQA
#       5
#
# C:\Program Files\Anaconda3\lib\site-packages\chainer\dataset\download.py in <module>()
#       6 import tempfile
# ...
